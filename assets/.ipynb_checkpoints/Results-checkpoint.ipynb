# %% [markdown]
# # Analyze JSON
# Author: Edward Schmuhl
#
# ---
#
# This notebook will show/visualize the results of the analysis

# %%
import os
import json

json_dir = './data/iherb_data/iherb_dataset_analyzed.json'
product_json = []

with open(json_dir,'rb') as f:
    product_json = json.load(f)

len(product_json)
# Out:
# 1214

# %%
review_counter = 0

for p_key in product_json.keys():
    p = product_json[p_key]
    p_review_id_list = {}
    p_review_id_unique_array = []
    
    for r in p["reviews"]:
        if r["id"] not in p_review_id_list:
            p_review_id_list[r["id"]] = r

    for r_id in p_review_id_list:
        _review = p_review_id_list[r_id]
        p_review_id_unique_array.append(_review)
    
    review_counter += len(p_review_id_unique_array)
    p["reviews"] = p_review_id_unique_array


print(review_counter)
# Out:
# 184791

# %%
for key in product_json.keys():
    product = product_json[key]
    condition_info = {}
    
    for review in product["reviews"]:
        for condition in review["condition"].keys():
            if condition.lower() not in condition_info:
                condition_info[condition.lower()] = {}
                condition_info[condition.lower()]["IMPROVED"] = 0
                condition_info[condition.lower()]["WORSEN"] = 0
                condition_info[condition.lower()]["NEUTRAL"] = 0
                
            condition_info[condition.lower()]["IMPROVED"] += review["condition"][condition]["IMPROVED"]
            condition_info[condition.lower()]["WORSEN"] += review["condition"][condition]["WORSEN"]
            condition_info[condition.lower()]["NEUTRAL"] += review["condition"][condition]["NEUTRAL"]

            
    product["condition"] = condition_info

# %% [markdown]
# # Condition Analysis

# %%
condition_dict = {}
condition_occurence_total = 0

for key in product_json.keys():
    product = product_json[key]
    for condition in product["condition"]:
        if condition not in condition_dict:
            condition_dict[condition] = {}
            condition_dict[condition]["IMPROVED"] = 0
            condition_dict[condition]["WORSEN"] = 0
            condition_dict[condition]["NEUTRAL"] = 0
        condition_dict[condition]["IMPROVED"] += product["condition"][condition]["IMPROVED"]
        condition_occurence_total += product["condition"][condition]["IMPROVED"]
        condition_dict[condition]["WORSEN"] += product["condition"][condition]["WORSEN"]
        condition_occurence_total += product["condition"][condition]["WORSEN"]
        condition_dict[condition]["NEUTRAL"] += product["condition"][condition]["NEUTRAL"]
        condition_occurence_total += product["condition"][condition]["NEUTRAL"]
        
print(f"Unique Conditions found: {len(condition_dict)} | Total Occurence: {condition_occurence_total}")
# Out:
# Unique Conditions found: 7200 | Total Occurence: 51369

# %%
top_improved_condition = []
top_worsen_condition = []

for c in condition_dict:
    top_improved_condition.append((c,condition_dict[c]["IMPROVED"]))
    top_worsen_condition.append((c,condition_dict[c]["WORSEN"]))
    
top_improved_condition = sorted(top_improved_condition, key=lambda tup: tup[1], reverse=True)
top_worsen_condition = sorted(top_worsen_condition, key=lambda tup: tup[1], reverse=True)

show_top = 15

print(f"Top {show_top} improved Conditions: ")
print(f"{top_improved_condition[:show_top]}")
print("---------------------------------------")
print(f"Top {show_top} worsen Conditions: ")
print(f"{top_worsen_condition[:show_top]}")
# Out:
# Top 15 improved Conditions:
# [('skin', 2879), ('sleep', 2470), ('anxiety', 585), ('candida', 572), ('inflammation', 445), ('depression', 403), ('acne', 396), ('colds', 388), ('thyroid', 386), ('blood pressure', 379), ('constipation', 339), ('allergies', 328), ('arthritis', 296), ('ibs', 287), ('joint pain', 286)]
# ---------------------------------------
# Top 15 worsen Conditions:
# [('skin', 191), ('sleep', 147), ('diarrhea', 99), ('nausea', 92), ('constipation', 91), ('headache', 86), ('headaches', 71), ('heartburn', 66), ('nauseous', 62), ('acne', 59), ('stomach upset', 50), ('bloating', 47), ('insomnia', 47), ('anxiety', 34), ('libido', 32)]

# %% [markdown]
# # Product Analysis

# %%
best_products = []
worst_products = []

for p_key in product_json.keys():
    p = product_json[p_key]
    improvements = 0
    worsen = 0
    for c in p["condition"]:
        improvements += p["condition"][c]["IMPROVED"]
        worsen += p["condition"][c]["WORSEN"]
    best_products.append((p["name"],improvements))
    worst_products.append((p["name"],worsen))
    
best_products = sorted(best_products, key=lambda tup: tup[1], reverse=True)
worst_products = sorted(worst_products, key=lambda tup: tup[1], reverse=True)

print(f"Top {show_top} Products with improved conditions: ")
print(f"{best_products[:show_top]}")
print("---------------------------------------")
print(f"Top {show_top} Products with worsen conditions: ")
print(f"{worst_products[:show_top]}")
# Out:
# Top 15 Products with improved conditions:
# [('Collagen Hydrolysate, Collagen Joint Care, 16 oz (454 g)', 229), ('Candida Support, 90 Veg Capsules', 212), ('Hyaluronic Acid + Chondroitin Sulfate, 60 Veggie Caps', 198), ('Thyroid Energy, 90 Veg Capsules', 197), ('5-HTP, 100 mg, 120 Veg Capsules', 186), ('Super Collagen, Type 1 & 3, 6,000 mg, 7 oz (198 g)', 179), ('Super Primrose, Evening Primrose Oil, 1300 mg, 120 Softgels', 171), ('Melatonin, 3 mg, 180 Capsules', 169), ('Melatonin, Time Release, Extra Strength, 5 mg, 100 Tablets', 168), ('Quercetin with Bromelain, 120 Veg Capsules', 166), ('Super Collagen + C, Type 1 & 3, 6,000 mg, 250 Tablets', 164), ('Probiotics, Original Formula, 60 Capsules', 150), ('Serrapeptase, 40,000 SPU, 90 Veggie Caps', 145), ('Natural Calm, The Anti-Stress Drink, Original (Unflavored), 16 oz (453 g)', 137), ('5-HTP, 100 mg, 60 Veggie Caps', 129)]
# ---------------------------------------
# Top 15 Products with worsen conditions:
# [('High Absorption Magnesium 100% Chelated with Albion Minerals, 100 mg, 120 Tablets', 37), ('Super Collagen, Type 1 & 3, 6,000 mg, 7 oz (198 g)', 35), ('Gentle Iron, 25 mg, 180 Vegetable Capsules', 26), ('Hyaluronic Acid + Chondroitin Sulfate, 60 Veggie Caps', 26), ('Thyroid Energy, 90 Veg Capsules', 23), ('DIM-plus, Estrogen Metabolism, 120 Vegetarian Capsules', 22), ('Super Collagen + C, Type 1 & 3, 6,000 mg, 250 Tablets', 20), ('Probiotics, Original Formula, 60 Capsules', 18), ('Biotin, Maximum Strength, 10,000 mcg, 100 Tablets', 17), ('Acai Berry Diet, Acai & Green Tea Superfoods, 60 Veggie Capsules', 15), ('Gold C, Vitamin C, 1,000 mg, 60 Veggie Capsules', 15), ('Melatonin, 3 mg, 60 Capsules', 15), ("Alive! Once Daily Women's Ultra Potency Multi-Vitamin, 60 Tablets", 14), ('Ashwagandha, 450 mg, 90 Veg Capsules', 14), ('Candida Support, 90 Veg Capsules', 14)]

# %% [markdown]
# # Product & Condition Analysis

# %%
supplement_for_condition = {}

for p_key in product_json.keys():
    p = product_json[p_key]
    
    for condition in p["condition"]:
        if condition not in supplement_for_condition:
            supplement_for_condition[condition] = []
            
        value = p["condition"][condition]["IMPROVED"]-p["condition"][condition]["WORSEN"]+p["condition"][condition]["NEUTRAL"]*0.1
        supplement_for_condition[condition].append((p_key,value))

for c in supplement_for_condition:
    supplement_for_condition[c] = sorted(supplement_for_condition[c] , key=lambda tup: tup[1], reverse=True)

# %%
find_condition = "stomach"

for c in condition_dict:
    if find_condition in c:
        print(f"{c} \n {condition_dict[c]} \n")
# Out:
# upset stomach
#  {'IMPROVED': 23, 'WORSEN': 26, 'NEUTRAL': 71}
#
# stomachache
#  {'IMPROVED': 4, 'WORSEN': 6, 'NEUTRAL': 17}
#
# stomach problem
#  {'IMPROVED': 5, 'WORSEN': 2, 'NEUTRAL': 7}
#
# stomach ache
#  {'IMPROVED': 6, 'WORSEN': 31, 'NEUTRAL': 38}
#
# stomach problems
#  {'IMPROVED': 47, 'WORSEN': 20, 'NEUTRAL': 57}
#
# stomach flu
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 13}
#
# stomach problems bladder issues
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach discomfort
#  {'IMPROVED': 11, 'WORSEN': 7, 'NEUTRAL': 13}
#
# stomach pain pain
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 2}
#
# stomach pain
#  {'IMPROVED': 17, 'WORSEN': 13, 'NEUTRAL': 47}
#
# stomach issues
#  {'IMPROVED': 38, 'WORSEN': 14, 'NEUTRAL': 61}
#
# stomach -
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 3}
#
# stomach digestive issues
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upset
#  {'IMPROVED': 36, 'WORSEN': 50, 'NEUTRAL': 78}
#
# stomach pains
#  {'IMPROVED': 8, 'WORSEN': 9, 'NEUTRAL': 17}
#
# stomachaches
#  {'IMPROVED': 3, 'WORSEN': 5, 'NEUTRAL': 1}
#
# sleep stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# depression stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach fat
#  {'IMPROVED': 2, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach irritation
#  {'IMPROVED': 4, 'WORSEN': 4, 'NEUTRAL': 4}
#
# stomach problems problems
#  {'IMPROVED': 3, 'WORSEN': 1, 'NEUTRAL': 4}
#
# stomach problems problems infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems infections
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach cramps
#  {'IMPROVED': 5, 'WORSEN': 26, 'NEUTRAL': 30}
#
# upset stomach stomach
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 4}
#
# sore stomach
#  {'IMPROVED': 0, 'WORSEN': 2, 'NEUTRAL': 2}
#
# digestive problems intolerant stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# lactose intolerant stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach distress
#  {'IMPROVED': 1, 'WORSEN': 4, 'NEUTRAL': 5}
#
# stomach illness
#  {'IMPROVED': 2, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach sick
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset.superb
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach acidity pain
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upsets
#  {'IMPROVED': 7, 'WORSEN': 1, 'NEUTRAL': 5}
#
# stomach problem disturbance
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach pains.(i'm
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach discomforts
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach troubble loss
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach burns
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 2}
#
# stomach discomfort pains
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# nauseous stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 2}
#
# stomach ache colitis syndrome
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset upset
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 3}
#
# stomach issue
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 4}
#
# stomach aches
#  {'IMPROVED': 17, 'WORSEN': 11, 'NEUTRAL': 17}
#
# stomach health
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 2}
#
# stomach viruses
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 2}
#
# upset stomach problems
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 3}
#
# stomach discomfort discomfort
#  {'IMPROVED': 0, 'WORSEN': 2, 'NEUTRAL': 0}
#
# stomach issues problems
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach pains problems
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach acid problem
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach bugs
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 2}
#
# stomach ache ache
#  {'IMPROVED': 1, 'WORSEN': 2, 'NEUTRAL': 2}
#
# stomachache symptoms
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach upset disease
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomachs
#  {'IMPROVED': 2, 'WORSEN': 1, 'NEUTRAL': 0}
#
# upset stomach upset
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach pains pain
#  {'IMPROVED': 2, 'WORSEN': 1, 'NEUTRAL': 1}
#
# stomach upset disturbances
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach gas
#  {'IMPROVED': 1, 'WORSEN': 2, 'NEUTRAL': 0}
#
# stomach infection infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach infections
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach irritation infections
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# heartburn stomach problems
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach gas issues
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach virus
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 3}
#
# bloated stomach
#  {'IMPROVED': 3, 'WORSEN': 1, 'NEUTRAL': 0}
#
# upset stomachs pains pains
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach pains pains
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 2}
#
# headaches stomachs
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# cramps stomach attack
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# gassy stomach attack
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach pain bladder problem
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach acids
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems feelings
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upset colitis
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems reactions
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# gassy stomach
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upsets cramps
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomach infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach bloating
#  {'IMPROVED': 8, 'WORSEN': 0, 'NEUTRAL': 3}
#
# stomach issues sugar
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# uneasy stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ulcer
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 4}
#
# stomach discomfort problems
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ulcer illness
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach disorder condition
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach cramping
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 2}
#
# stomach issues pain
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach bug
#  {'IMPROVED': 2, 'WORSEN': 1, 'NEUTRAL': 3}
#
# stomach disorders
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# gastritis stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ulcer ulcer
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ills pressure ills pressure
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach ills pressure
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach problems digestive issues
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach issues pressure
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach issues issues
#  {'IMPROVED': 4, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach demons
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach reflux
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ache cramps
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ulcers
#  {'IMPROVED': 2, 'WORSEN': 1, 'NEUTRAL': 5}
#
# stomach acid problems
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach probles
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach stress
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ailment
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach cramps issues
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 2}
#
# stomach upset cramps
#  {'IMPROVED': 0, 'WORSEN': 2, 'NEUTRAL': 0}
#
# stomach rumbles
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomache ache
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach troubles
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 3}
#
# jitters stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# colds stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# upset stomach issues
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 2}
#
# reflux stomach
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach problems distress
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach reactions
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach pain fatigue pain
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach cramp churning
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach churning
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach gas problem
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# constipation stomach
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 2}
#
# stomach aches pains
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach bloatness
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach nerves
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach bug ache flu infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ache flu infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach flu infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach virus bug
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach trouble
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 5}
#
# anemia stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach surgery trouble
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# nausea stomach cramps
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# upset stomach cramps
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach flu pain
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach flu sickness
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomach remedy sickness
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach discomfort issues
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach pain problem
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ache stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems pinching
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach pinching
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset infection
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach health infections
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach flu flu flu
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach flu flu
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach aches pressure
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 2}
#
# stomach discomfort ache
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach - issues
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach pain pain pressure
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach inflammation
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomache problems
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 1}
#
# ulcerated stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach bloating ref
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach cramps cramps
#  {'IMPROVED': 0, 'WORSEN': 2, 'NEUTRAL': 0}
#
# stomach bloated
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 2}
#
# fibromyalgia stomach issues
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# bloated issue stomach issue
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# bloated stomach issue
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# diarrhoea stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach noises
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomache
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomachache pain
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach distress aches
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach nausea
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach bloat
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach burning
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 3}
#
# leg muscles stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upset ulcers
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach pain pain flu
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach pain flu
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach ulcer ulcers
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach lining
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomache issues
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach ulcer ulcer infection
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ulcer infection
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach ulcer health
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach acke
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomache
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach aching
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomach discomfort
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ills
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach cramp
#  {'IMPROVED': 0, 'WORSEN': 2, 'NEUTRAL': 1}
#
# heartburn stomach
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach bloatedness
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach gurgling
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach upset upset issues
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach problems pain
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach infection
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 2}
#
# stomach ache throat
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach condition
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# asd stomach issues
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach symptoms
#  {'IMPROVED': 1, 'WORSEN': 1, 'NEUTRAL': 1}
#
# stomach cramp cramp
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomached aches
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems problem
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach issues infections
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach complaints
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach situations
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomache cramps
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ulcer pain
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach pain hernia
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach muscles
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# gastric stomache
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach burn
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach grumbling
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach spasms spasms
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach trouble cramping reflux
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# bloating stomach
#  {'IMPROVED': 1, 'WORSEN': 2, 'NEUTRAL': 1}
#
# stomach injury
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomach virus
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach /
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach problems problems{i'll
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems{i'll
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# digestive concerns stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach woes
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# travel stomach upsets
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach problems ailments
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomachs issues ache issues
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach disorder
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach cramps pains
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach distress cramping
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach upset distress
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach problems bloating
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# diarrhea stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach aches aches
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach irritations stress
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach sleeper congestion
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach problems issues
#  {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems stomach
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach ache issues
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset upset side
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset side
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach side
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# sleep stomach pain
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# crampy stomach pain
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach pain distress
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomache upset
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach issues problem
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# inflammation stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# arthritis pain stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach complaints complaints
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upset hernia symptoms
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach issues stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# digestive troubles(acid stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ailments
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset pain pain
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problem problem
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach skin loss
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach hurt
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach ache bladder problem
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach cancer problems
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# digestive stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach indigestion
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach upsets problems
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach painful
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach troubles issues
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# thyroid stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset disorders
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach ache tummy
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# ibs stomach
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach acid issue
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# sore stomache
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# upset stomach)
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# peptic ulcer stomach
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach aci
#  {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}
#
# stomach aches throats
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upsets problems ulcers
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach problems ulcers
#  {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}
#
# stomach bleeding
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}
#
# stomach upset retention
#  {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}

# %%
get_top = 10
get_condition = "stomach issues"

print(f"Best {get_top} Products for {get_condition} ")

indexer = 1
for _t in supplement_for_condition[get_condition][:get_top]:
    print(f"({indexer}) {product_json[_t[0]]['name']} | Product ID: {_t[0]} | Score: {_t[1]} ")
    indexer += 1
# Out:
# Best 10 Products for stomach issues
# (1) PB8 With Lactobacillus & Bifidobacterium, 120 Veggie Caps | Product ID: 5930 | Score: 3.3
# (2) Slippery Elm, 400 mg, 100 Capsules | Product ID: 796 | Score: 3.2
# (3) PepZin GI, Zinc-L-Carnosine Complex, 120 Veggie Caps | Product ID: 2467 | Score: 2.1
# (4) Primadophilus, Kids, Orange, 3 Billion CFU, 30 Chewable Tablets | Product ID: 18537 | Score: 1.2
# (5) Super Enzymes, 180 Capsules | Product ID: 857 | Score: 1.2
# (6) Digest Gold, with ATPro, 180 Capsules | Product ID: 7056 | Score: 1.1
# (7) Ginger Root, 550 mg, 100 Veg Capsules | Product ID: 592 | Score: 1.1
# (8) LactoBif Probiotics, 5 Billion CFU, 60 Veggie Capsules | Product ID: 64006 | Score: 1.1
# (9) Mastic Gum, 120 Vegetarian Capsules | Product ID: 3450 | Score: 1.1
# (10) 20+ Bio Active Manuka Honey, 1.1 lb (500 g) | Product ID: 59963 | Score: 1.0

# %%
get_reviews_from = "2162"


get_reviews_from_product = product_json[get_reviews_from]

print(get_reviews_from_product["condition"].keys())

indexer_review = 1
for review_json in get_reviews_from_product["reviews"]:
    print("\n")
    print(f"{indexer_review} : {review_json['text']}")
    print(f"{review_json['condition']}")
    indexer_review += 1
# Out:
# dict_keys(['reflux', 'indigestion', 'stomach pain', 'stomach upset', 'ulcer', 'gastritis', 'stmptoms', 'heartburn', 'blood pressure', 'stomach aches', 'digestive issues', 'gastric problem', 'nauseous', 'stomach disorders', 'diarrhea', 'gastritis stomach', 'upset stomach', 'stomach ulcer ulcer', 'colon ulcer', 'stomach ills pressure ills pressure', 'blood pressure ills pressure', 'stomach ills pressure', 'oesophagitis', 'reflux pressure', 'reflux problems', 'reflux symptoms', 'stomach stomach', 'inflammation', 'stomach problems digestive issues', 'ulcers digestive issues', 'stomach digestive issues', 'heartburn problem', 'stomach distress', 'stomach issues pressure', 'gerd symptoms hernia', 'gerd hernia', 'hiatal hernia', 'hernia', 'stomach issues issues', 'stomach issues', 'bloating', 'sleep', 'stomach demons', 'gerd', 'ulcers'])
#
#
# 1 : DGL. Really good that you stock this product as most OS online stores won’t ship these products to Aust. Certainly helps with  maintaining your gut health Marshall
# {}
#
#
# 2 : DGL is good for acid reflux.. I take it before I eat my big meal for the day, (supper).   I take it to prevent acid reflux, and it does help. I have been taking it about a year.
# {'reflux': {'IMPROVED': 2, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 3 : Good for indigestion!. I use this product for several years to soothe my stomach and it works
# {'indigestion': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 4 : love the taste. excellent.  good for my gut when most things are too much.
# {}
#
#
# 5 : DGL. Great fix for stomach pain, costs the stomach lining with healthy non glycerine licorice.  No sugar!
# {'stomach pain': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 6 : Did not receive  product that was ordered.. Did not receive this product of 3:1 as ordered. Sent picture of label as requested and e-mail came back wanting more pictures. Pictured showed it was not the 3:1 but the suger free DGL. I'm a very busy person and don't have time to do iHerb's job as well
# {}
#
#
# 7 : ENZ MATIC Therapy  DGL tablets  no fructose formula. thank you for asking me for a review.    They tasted pleasant, and were helpful for my stomach, but after using them for a few days, I happened to look at the 'other ingredients, and found to my astonishment that there was sorbitol and mannitol in the ta
# {}
#
#
# 8 : NOT WHAT IS PICTURED OR DESCRIBED!!. BEWARE! The product listed is not what you get! I thought I was purchasing 3:1 Deglycyrrhizinated Licorice, 760 mg licorice content. Purchased 3 bottles. I received a different version in the mail. All 3 bottles only have 75 mg of DGL, no where near 760m
# {}
#
#
# 9 : Disappointed..... they changed the formula.  GutGard™ Deglycyrrhizinated Licorice (DGL) Root Extract is 75 mg per 3 tablets. and the glycine amount is 150 mg per 3 tablets.  and here the suggested use is 2 tablets 20 minutes before a meal. and in the label,  3 tablets aft
# {}
#
#
# 10 : GI. Helps keep health intestinal lining
# {}
#
#
# 11 : POORLY ADVERTISED - Now new product. I bought this product after reading the specifications on iHerb's website where it specifies that each tablet contains 760mg of licorice extract - when it arrived the bottle says each tablet contains 75mg licorice extract - that's less than 10% claimed o
# {}
#
#
# 12 : The product they send is not what is on this WebSite. They have changed the amount of DGL from 760mg to 75mg. This stuff does not work anymore. The website displays the old label but when you get the stuff it is in a bottle with different ingredients. Even worse when you try to return it. They replaced the
# {}
#
#
# 13 : Change In Formulation?. I had used this product daily for years.  Two tablets each evening. The last bottle didn't taste the same.  It tasted yucky to me.  I noticed the bottle was a tad different and the dose had gone from 2 to 3 chewable tablets.  I hope they bring back the p
# {}
#
#
# 14 : Really works. I chew one of these each morning and have found that ittteally helps with stomach upset.
# {'stomach upset': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 15 : Dgl. This product has helped me with gerd. I will continue to order this product and take this 20 min. Before each meal. I also like the flavor.
# {}
#
#
# 16 : Great Product. This product is very good and it really works!  I would definitely recommend this product for anyone who has heart burn.
# {}
#
#
# 17 : cant live without it!. it is really a God's send to me...helps stomach pain instantly!
# {'stomach pain': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 18 : Helps Indigestion. I take these for my ulcer along with Zinc-L-Carnosine and Marshmallow root.  They definitely help, but as they contain licorice which still can increase your cortisol (although only a small amount), I take them in the morning and occasionally at lunch ti
# {'ulcer': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
#  https://en.wikipedia.org/wiki/Sorbitol
# {}
#
#
# 20 : a great way to get DGL. we've used the for years so it's nice to be able to get them so conveniently
# {}
#
#
# 21 : Terrible shopping experience !!!. To date I have not received the products, this company has no contact with its consumers. A shame!
# {}
#
#
# 22 : Great for acid reflux. I take 1/2 to 2 a day. I no longer need antacids and can eat pretty much what I want. This works great with marshmallow for extra soothing protection.
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 23 : Amazing. Truly helps with reflux and gastritis in the short and long term!
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'gastritis': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 24 : Dgl for gerd. Love the taste and have noticed a substantial difference in my stmptoms
# {'stmptoms': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 25 : Not bad. NOT BAD
# {}
#
#
# 26 : Heartburn / menopause. It has helped a small amount with the heartburn. But oddly enough, it has really helped with menopause, hot flushes have gone!
# {'Heartburn': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'heartburn': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 27 : Stomach good. Lowers Blood Pressure .so be careful
# {'Blood Pressure': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 28 : Really seems to help digestion. I've been using this to balance my digestion - particularly acid reflux and it does seem to be helping. I think you do need to be conscentious and take it according to directions.
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 29 : Deglycyrrhizinated Licorice. Very good for mild stomach aches, or that too stuffed feeling.  Satisfies me for the desire  for desert too .
# {'stomach aches': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 30 : Not good for me. Not sure if effective as it caused heartburn and so I stopped using it.
# {'heartburn': {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}}
#
#
# 31 : This product have a great features. Great
# {}
#
#
# 32 : WOW. Ideal after coming off LOSEC  which I had been on 12yrs.... helped immensely
# {}
#
#
# 33 : Effective. I am giving this product 5 stars on behalf of my sister. We were out having lunch one day and noticed me taking these afterwards, so asked to try some. Next time she came to my house she asked to 'borrow' and that was the last I saw of them. Now when she
# {}
#
#
# 34 : This is a natural product. This product has helped me with my digestive issues.
# {'digestive issues': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 35 : DGL ENZYMATIC THERAPHY. As I suffer from Gord, I have found these tablets help to sooth and calm my stomach
# {}
#
#
# 36 : Gave me indigestion. I tried this, but it doesn't work for me.
# {'indigestion': {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 0}}
#
#
# 37 : Professional Engineer. Works well in the evening.
# {}
#
#
# 38 : Beware. I was having acid reflux and took 2-3 of these a day which helped that problem.  I've had adrenal insufficiency for several years, but developed a problem that anyone can get from licorice.  It's called Pseudohyperaldosteronism, and causes you to become
# {'reflux': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 39 : Really works. This has a medium licorice taste, and it work for upset gut very well. I have used DGL for years. Occasionally I still use the Tums type of antacid, but this is my first choice.
# {}
#
#
# 40 : Great for Silent Reflux. You don't realise how well this works until you stop taking it and then your reflux comes back within days.  HOwever it also gave me fluid retention and I found that switching to a capsule without the artificial sweetners solved that problem.
# {'Reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'reflux': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 41 : Good product. The item came on time and has proved a great benefit for my gastric problem. I will be ordering more soon.
# {'gastric problem': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 42 : Healed my Stomach Lining. I have a sensitive stomach. I was never able to drink coffee or other acidic drinks without feeling nauseous afterwards. I started taking this DGL chewing 3-4 tabs daily. After about a month I was able to drink coffee again. I now drink 3 cups of coffee
# {'nauseous': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 43 : Great Gut Healer. a product i can rely on anytime and i-herbs fast service is so commendable.
# {}
#
#
#  It seems to work quite quickly--if I feel that i might be about to have a reflux attack, I chew 1 or 2 of these and protect my oesophagus straight away.
# {'reflux': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
#  Prefer the 'original' (which are more licorice-tasting) but these are great, too.
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 46 : Sorbitol. I am allergic to sorbitol which this has as well as magnesium stearate. The Ultra Chocolate has milk, and the Ultra Caramel has milk plus lots of other questionable things Not impressed. People with stomach disorders don't need extra allergens in their d
# {'stomach disorders': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 47 : terrible!. I think I might be sensitive to this product,and I had diarrhea and felt  fatigued after taking this tablets...Won't buy this again..
# {'diarrhea': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 48 : Great Product. Nice tasting and seem to do a pretty good job
# {}
#
#
# 49 : DGL is fantastic. After the first container of DGL my symptoms of severe heartburn started to disappear.  Now I take my DGL and have not had any heartburn for over a week.  I actually feel well again after many years of suffering.
# {'heartburn': {'IMPROVED': 0, 'WORSEN': 1, 'NEUTRAL': 1}}
#
#
# 50 : Thought I had Angina for years! Thank God I found this!. Well what do you know after taking this for a case of acid reflux my heart burn disappeared and the case of Angina I thought I had for decades was stomach related. They say a spoon full of sugar makes the medicine go down. This is candy like without all
# {'reflux': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 51 : Helps with gastritis. When I get upset stomach or heartburn this seems to help with my gastritis.
# {'gastritis stomach': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'upset stomach': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'heartburn': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
#  I had more control over my food eating.
# {}
#
#
# 53 : Wonderful!. I've been using this for many years and as long as you chew them BEFORE eating, they are a huge help.    Taste is good also.
# {}
#
#
# 54 : Don't Care for the Taste. If you enjoy strong licorice flavor, this one may be for you.
# {}
#
#
# 55 : Like the taste. I have different types of supplements for reflux and stomach disturbs but I prefer this one. It really calms my upper digestive system.
# {'reflux': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 56 : Help at night!. I only need to use these at night and they work well. I continually use them so always keep them on hand. Taste is great too and am thankful that they are naturally sugar free so hopefully don't destroy my teeth.
# {}
#
#
# 57 : DGL Tablets. These are good-tasting tabs.  I had used a capsule-type DGL about 4 years ago to cure a stomach ulcer.  Within 2 months, a second scoping showed no signs of any ulcer.  This time, I'm taking DGL to help cure a colon ulcer and I'm sure it will help.  Boug
# {'stomach ulcer ulcer': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'colon ulcer': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
#  This is safe for people who want to treat stomach ills, like acid stomach and ulcers, without unwanted higer blood pressure.
# {'stomach ills pressure ills pressure': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'blood pressure ills pressure': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'stomach ills pressure': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'blood pressure': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 59 : Great for acid reflux and gastritis. Great for acid reflux and gastritis!
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'gastritis': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 60 : These taste AWFUL!. I like the flavor of black licorice but these taste like a handful of rye and black licorice mixed together. I loved that they were sugar free but could not stand to choke them down prior to every meal. I've since purchased the German Chocolate which hav
# {}
#
#
# 61 : Will not buy again!. I usually buy another brand but it was out of stock, so now I'm stuck with these vile tasting tablets...they are revolting! I'd give no stars if I could!
# {}
#
#
# 62 : Great service. Unsure about ordering from UK but excellent service, despatched within hours and arrived 10 days later, no tax. Item twice the price here and has been very soothing and healing for my oesophagitis,together with raised pillow.Have since re-ordered,nothing
# {'oesophagitis': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 63 : Works great, tastes horrible. I can't chew it, I tried.   The odor and taste is terrible but ... it works.  And I bought it to work.  So I just go ahead and take it.
# {}
#
#
# 64 : Effectiveness of DGL for reflux treatment.. Licorce contains an ingredient that can raise blood pressure, but this product has removed it. I asked my doctor about using DGL and he told me it was a standard therapy in Europe. I have found it very effective. It stimulates the body to produce a natur
# {'reflux pressure': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'blood pressure': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 65 : Enzymatic TherapyDGL. Excellent product
# {}
#
#
# 66 : get past the taste, b/c this works VERY WELL. a strong taste, but works very well!!
# {}
#
#
# 67 : My favorite DGL brand. No sugar, seems to have an effect on my heartburn. Make sure you let them dissolve in your mouth for max effect. Chewing and swallowing does not mix DGL with saliva.
# {'heartburn': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 68 : In combination with slippery elm just great .. This matched with slippery elm lozengers is a great combination , my days of using Nexium with all the side efects are now gone .Using this before meals or when i need it , relaxes me and makes my body feel good.Can highly recomend.
# {}
#
#
# 69 : Enzymatic Therapy, DGL . Seem to be working but need a longer term trial.
# {}
#
#
# 70 : great help for digestion. DGL has changed my life.  I don't have symptoms of acid indigestion at all since I started using DGL before my meals.  Great product
# {'indigestion': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 71 : Good quality, reasonable price. I take DGL to control my acid reflux and am very satisfied with Ezymatic Therapy's brand. It is reasonably priced and arrives quickly and dependably.
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 72 : GREAT PRODUCT. Even natural pills work different for everyone. We need to use it in order to experience. This is a great product to try it.
# {}
#
#
# 73 : DGL is great.... DGL is great and it helps me a lot, but I rather it  had no sorbitol and manitol, which are not beneficiary should be better left alone by persons with digestive issues. I would have given it 5 stars if it wasn't for that.
# {'digestive issues': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 74 : Too Strong Tasting. I can hardly stomach the taste of these chewable DGL tablets.  Very strong licorice flavor, bordering on bitter and gaggy.  I'm not a licorice-flavor fan to begin with, so I'm sure that factors into my opinion.  I bought the sugarless German chocolate fl
# {}
#
#
# 75 : DGL Enzymatic Therapy. Wonderful, take two three times a day for reflux problems.  I love liquorice besides.
# {'reflux problems': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 76 : effective. good for short term relief
# {}
#
#
# 77 : Many thanks!. My husband was out of his DGL, and I frantically searched on line to fine a provider.  iHerb.com had the best price and delivered within 2-3 days.  Great service, excellent product.
# {}
#
#
# 78 : Decent product. While this product works well, it takes horrible!  They are chew able tabs and I can only tolerate them if drinking something strong right after half chewing them. There are certainly some beater tasting alternatives!
# {}
#
#
# 79 : Works better than Antacids. Been taking this for about 3 months now and does help with acid reflux symptoms. Am cutting back to a as needed basis.
# {'reflux symptoms': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 80 : calms the burn. If you have an upset  or burning stomach stomach, this stuff is great, although the taste is not.  You just get used to it.
# {'stomach stomach': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 81 : Better ingredients BUT not as effective as chewables. I have now tried 4 different brands and while they all work, I now found one that has the least offensive additional ingredients - Nature's Plus DGL.
# {}
#
#
# 82 : Seems ok. Seems ok. Sometimes I sneeze when I take a couple of these on an empty stomach. But not always.
# {}
#
#
# 83 : Great stuff!. DGL licorice is wonderful for calming an upset stomach, healing the gut and reducing inflammation in the GI tract. I love the taste too!
# {'upset stomach': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'inflammation': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 84 : This is a must if you have any stomach problems. This is great for ulcers, stomach digestive issues, and regularity.  Love it and it has really good ingredients without the chemicals.
# {'stomach problems digestive issues': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'ulcers digestive issues': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'stomach digestive issues': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 85 : This dgl is helpful. This form of dgl helps with my reflux symptoms as I take it about 20-30 before I eat breakfast, in between lunch and dinner and before I go to bed. I believe it helps heal/soothe my stomach lining as I had insignificant tissue inflammation after an endos
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 86 : Awesome. Very good product
# {}
#
#
# 87 : Great Stuff!!. If you have digestive issues & do not want to take a conventional pepto method....try this!!!
# {'digestive issues': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 88 : Enzymatic Therapy, DGL. I like Natural factor's DGL better than the Enzymatic Therapy's.  I couldn't take this one because of smell.
# {}
#
#
# 89 : Taste really bad, but does help.. I suggest cutting it up ijn small pieces and not chewing, it taste horribel! Helps some but doesn't fix the problem.
# {}
#
#
# 90 : It works... This really helps my stomach but I think it tastes terrible......but when my stomach hurts I'll take anything so I get over the bad taste for the sake of my stomach.
# {}
#
#
# 91 : Works great!. This products really helps my heartburn problem.  I highly recommend using DHL daily.
# {'heartburn problem': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 92 : DGL Benefits. DGL is a great soother of stomach distress, and Enzymtiz Therapy has the best product for it.
# {'stomach distress': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 93 : DGL Works!!. This is a great brand, and I ordered a few bottles for my dad cause he was having stomach issues.  It's all natural and the enzyme which causes high blood pressure has already been removed. I ordered this from iHerb.com and it arrived quickly.  My dad wa
# {'stomach issues pressure': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'blood pressure': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 94 : Excellent. Recommended to me by a medical person and reflexologist
# {}
#
#
#  I never take anti-acid drugs any more.
# {'heartburn': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 96 : Glad not to have to use medications. DGL never fails to resolve acid reflux for me, or the rare occasions in the past where I had that painful ulcerative feeling in my stomach.
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 97 : Soothing. I have used this for digestion generally on a regular basis and it is very helpful. I use the sugarless tablets.
# {}
#
#
# 98 : Stops GERD symptoms. If you suffer from GERD, 'acid stomach', hiatal hernia, etc, try DGL. The right balance is necessary - too much, and it doesn't work. Try just one tablet when you need relief from burning stomach.
# {'GERD symptoms hernia': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'GERD hernia': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}, 'hiatal hernia': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 99 : enzymatic therapy DGL Chewable Tablets. I could not live without this product especially at night. I use just like you would use Tums for acid indigestion.Love the taste I love licorice. Great product for someone with hernia and all that goes with that. Dr. Sherri Rodgers recomended this in he
# {'hernia': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 100 : Helping Stomach Issues. This is an excellent, natural product that seems to be helping my stomach issues.
# {'Stomach Issues issues': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}, 'stomach issues': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 101 : Great Product. Great Product, Great Price, Great Delivery.  Thanks Mike LV, NV.
# {}
#
#
# 102 : Great product!. You don't have to take this everyday. I take it whenever I feel a slight discomfort ( bloating, indigestion) or when I figure this will help me to feel better after a big meal..normally one tablet before meal depending on the severity. Can be taken after
# {'bloating': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 103 : good stuff. taste good / does the job, but must remind self it's not candy;)
# {}
#
#
# 104 : Does not appear to be completely deglycinerrated.. Product interferes with sleep quality and quantity, especially if used at the recommended dose.  Although this product is touted as a cortisol control agent, I can't recommended it for this purpose.    It should be used as a digestive aide only and not b
# {'sleep': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 105 : Enzymatic Therapy, DGL, 100 Chewable Tablets. Best tasting of all the DGL tried.
# {}
#
#
# 106 : some relief. i use this b4 meals and as an aid to heartburn and indigestion. i have had digestive discomforts for years and this helps coat my stomach and get rid of upper GI conditions
# {'heartburn': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 107 : Enzymatic Therapy DGL Chewable Tabs. This has been an excelllent answer to reflux! It is easy to use and leaves no side-effects.
# {'reflux': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 108 : Great Heartburn Relief. These work as well as Tums, and are better for my stomach.
# {'Heartburn': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 109 : Kiliah. I agree with other respondents.  These things taste terrible!  I will use them to avoid loss of money I spent as it is not possible to return opened containers.  As I have stated before it is unfortunate that you do not offer a customer satisfaction guar
# {}
#
#
# 110 : Seems to be more effective than DGL without L-Glycine. I have used this product that also contains L-Glycine and Natural Factors DGL without L-Glycine and think this is more effective at keeping the stomach demons calm.
# {'stomach demons': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 111 : dgl, enzymatic therapy. taking it for years
# {}
#
#
# 112 : Very Good Product. This is a very good product. Because of its strong taste, I found out that just keeping it in the mouth and allowing it to dissolve little by little makes it a little more bearable. I will buy it again.
# {}
#
#
# 113 : What is title. I have been using DGL for quite sometime and i'm very happy with this product
# {}
#
#
# 114 : DGL. works at it should for GERD
# {'GERD': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
# 115 : Soothing. I was diagnosed with 5 ulcers. 2 months later I'm healed. I also took OMX12 + 2x a day. As for the taste you really get use to it. At first though I wanted to gag.
# {'ulcers': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
#
#
# 116 : Enzymatic Therapy DGL. Been taking DGL for 2 years and although it does not cure' my GERD, it does help keep it in check and not get any worse.
# {'GERD': {'IMPROVED': 1, 'WORSEN': 0, 'NEUTRAL': 0}}
#
#
#  for many years. This product has allowed me to stop taking Nexum.
# {'reflux': {'IMPROVED': 0, 'WORSEN': 0, 'NEUTRAL': 1}}
